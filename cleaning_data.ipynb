# %%
import pandas as pd
# Used Car Price & Market Analysis
#Cleaning tasks:
#• Convert ₹/lakhs into numeric values
#• Convert mileage and engine values
#• Handle missing values
#• Standardize brand/model names
#• Remove duplicate listings
##• Detect unrealistic mileage/prices
#• Extract numerical information from text

df=pd.read_csv(r"C:\Users\LENOVO\Downloads\cardekho_dataset.csv")
df
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (15411, 14)

# %%
df.rename(columns={'Unnamed: 0': 'serial_number'}, inplace=True)

df
# Out:
#        serial_number         car_name     brand     model  vehicle_age  \
# 0                  0      Maruti Alto    Maruti      Alto            9
# 1                  1    Hyundai Grand   Hyundai     Grand            5
# 2                  2      Hyundai i20   Hyundai       i20           11
# 3                  3      Maruti Alto    Maruti      Alto            9
# 4                  4    Ford Ecosport      Ford  Ecosport            6
# ...              ...              ...       ...       ...          ...
# 15406          19537      Hyundai i10   Hyundai       i10            9
# 15407          19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408          19541      Skoda Rapid     Skoda     Rapid            6
# 15409          19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410          19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# ...

# %%
df.columns = df.columns.str.title()
df.columns
# Out:
# Index(['Serial_Number', 'Car_Name', 'Brand', 'Model', 'Vehicle_Age',
#        'Km_Driven', 'Seller_Type', 'Fuel_Type', 'Transmission_Type', 'Mileage',
#        'Engine', 'Max_Power', 'Seats', 'Selling_Price'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns='Serial_Number',inplace=True)
df
# Out:
#               Car_Name     Brand     Model  Vehicle_Age  Km_Driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       Seller_Type Fuel_Type Transmission_Type  Mileage  Engine  Max_Power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df.head(2)
# Out:
#         Car_Name    Brand  Model  Vehicle_Age  Km_Driven Seller_Type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
#
#   Fuel_Type Transmission_Type  Mileage  Engine  Max_Power  Seats  \
# 0    Petrol            Manual     19.7     796       46.3      5
# 1    Petrol            Manual     18.9    1197       82.0      5
#
#    Selling_Price
# 0         120000
# 1         550000

# %%
# clean car_name columns

df['Car_Name']=df['Car_Name'].str.strip()
df['Car_Name']
# Out:
# 0            Maruti Alto
# 1          Hyundai Grand
# 2            Hyundai i20
# 3            Maruti Alto
# 4          Ford Ecosport
#               ...
# 15406        Hyundai i10
# 15407      Maruti Ertiga
# 15408        Skoda Rapid
# 15409    Mahindra XUV500
# 15410         Honda City
# Name: Car_Name, Length: 15411, dtype: object

# %%
df['Car_Name'].duplicated().sum()
# Out:
# np.int64(15290)

# %%
# clean brand clean
df['Brand'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Ford', 'Renault', 'Mini', 'Mercedes-Benz',
#        'Toyota', 'Volkswagen', 'Honda', 'Mahindra', 'Datsun', 'Tata',
#        'Kia', 'BMW', 'Audi', 'Land Rover', 'Jaguar', 'MG', 'Isuzu',
#        'Porsche', 'Skoda', 'Volvo', 'Lexus', 'Jeep', 'Maserati',
#        'Bentley', 'Nissan', 'ISUZU', 'Ferrari', 'Mercedes-AMG',
#        'Rolls-Royce', 'Force'], dtype=object)

# %%
df['Brand'].duplicated().sum()
# Out:
# np.int64(15379)

# %%
df['Brand']=df['Brand'].str.title()
df['Brand']
# Out:
# 0          Maruti
# 1         Hyundai
# 2         Hyundai
# 3          Maruti
# 4            Ford
#            ...
# 15406     Hyundai
# 15407      Maruti
# 15408       Skoda
# 15409    Mahindra
# 15410       Honda
# Name: Brand, Length: 15411, dtype: object

# %%
## clean Model columns
df['Model']=df['Model'].str.title()
df['Model']
# Out:
# 0            Alto
# 1           Grand
# 2             I20
# 3            Alto
# 4        Ecosport
#            ...
# 15406         I10
# 15407      Ertiga
# 15408       Rapid
# 15409      Xuv500
# 15410        City
# Name: Model, Length: 15411, dtype: object

# %%
df['Model'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Model'].duplicated().sum()
# Out:
# np.int64(15291)

# %%
df.head(2)
# Out:
#         Car_Name    Brand  Model  Vehicle_Age  Km_Driven Seller_Type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
#
#   Fuel_Type Transmission_Type  Mileage  Engine  Max_Power  Seats  \
# 0    Petrol            Manual     19.7     796       46.3      5
# 1    Petrol            Manual     18.9    1197       82.0      5
#
#    Selling_Price
# 0         120000
# 1         550000

# %%
# clean Vehicle_Age columns
df['Vehicle_Age'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Vehicle_Age'].duplicated().sum()
# Out:
# np.int64(15387)

# %%
df['Vehicle_Age'].dtypes
# Out:
# dtype('int64')

# %%
## clean Km_Driven columns
df['Km_Driven'].unique()
# Out:
# array([ 120000,   20000,   60000, ...,    9229,   10723, 3800000],
#       shape=(3688,))

# %%
df[(df['Km_Driven'] <0) |  (df['Km_Driven'] >80000000)].sum()
# Out:
# Car_Name               0
# Brand                  0
# Model                  0
# Vehicle_Age            0
# Km_Driven              0
# Seller_Type            0
# Fuel_Type              0
# Transmission_Type      0
# Mileage              0.0
# Engine                 0
# Max_Power            0.0
# Seats                  0
# Selling_Price          0
# dtype: object

# %%
df['Km_Driven'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Km_Driven'].duplicated().sum()
# Out:
# np.int64(11723)

# %%
## clean Seller_Type columns

df['Seller_Type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df['Seller_Type']=df['Seller_Type'].str.strip()
df['Seller_Type']
# Out:
# 0        Individual
# 1        Individual
# 2        Individual
# 3        Individual
# 4            Dealer
#             ...
# 15406        Dealer
# 15407        Dealer
# 15408        Dealer
# 15409        Dealer
# 15410        Dealer
# Name: Seller_Type, Length: 15411, dtype: object

# %%
df['Seller_Type']=df['Seller_Type'].str.title()
df['Seller_Type']
# Out:
# 0        Individual
# 1        Individual
# 2        Individual
# 3        Individual
# 4            Dealer
#             ...
# 15406        Dealer
# 15407        Dealer
# 15408        Dealer
# 15409        Dealer
# 15410        Dealer
# Name: Seller_Type, Length: 15411, dtype: object

# %%
df['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer              9539
# Individual          5699
# Trustmark Dealer     173
# Name: count, dtype: int64

# %%
df['Seller_Type'].isna().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#         Car_Name    Brand  Model  Vehicle_Age  Km_Driven Seller_Type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
#
#   Fuel_Type Transmission_Type  Mileage  Engine  Max_Power  Seats  \
# 0    Petrol            Manual     19.7     796       46.3      5
# 1    Petrol            Manual     18.9    1197       82.0      5
#
#    Selling_Price
# 0         120000
# 1         550000

# %%
## clean Fuel_Type columns

df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol      7643
# Diesel      7419
# CNG          301
# LPG           44
# Electric       4
# Name: count, dtype: int64

# %%
df['Fuel_Type'].duplicated().sum()
# Out:
# np.int64(15406)

# %%
# clean Transmission_Type columns
df['Transmission_Type'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Transmission_Type'].value_counts()
# Out:
# Transmission_Type
# Manual       12225
# Automatic     3186
# Name: count, dtype: int64

# %%
df['Transmission_Type'].str.strip()
# Out:
# 0           Manual
# 1           Manual
# 2           Manual
# 3           Manual
# 4           Manual
#            ...
# 15406       Manual
# 15407       Manual
# 15408       Manual
# 15409       Manual
# 15410    Automatic
# Name: Transmission_Type, Length: 15411, dtype: object

# %%
## clean Mileage columns
df['Mileage'].unique()
# Out:
# array([19.7 , 18.9 , 17.  , 20.92, 22.77, 20.36, 20.51, 18.15, 16.6 ,
#        22.32, 19.64, 14.41, 28.09, 25.2 , 19.27, 28.4 , 12.99, 21.4 ,
#        20.85, 16.09, 19.67, 17.4 , 13.6 , 26.59, 17.7 , 17.19, 13.  ,
#        23.01, 18.6 , 17.92, 15.1 , 23.4 , 22.54, 18.  , 21.  , 15.4 ,
#        20.89, 26.6 , 22.5 , 17.8 , 20.54, 17.3 , 25.  , 24.  , 18.16,
#        21.21, 14.  , 16.8 , 25.17, 24.3 , 18.5 , 23.84, 18.78, 11.74,
#        25.1 , 21.01, 22.74, 21.9 , 15.6 , 19.1 , 22.07, 22.  , 23.1 ,
#        23.  , 19.08, 18.27, 23.9 , 16.1 , 19.81, 19.44, 18.59, 20.62,
#        17.01, 17.5 , 12.05, 25.83, 21.79, 13.7 , 16.47, 20.7 , 10.91,
#        25.8 , 25.32, 19.87, 18.7 , 14.4 , 22.69, 20.73, 16.55, 20.  ,
#        21.5 , 24.7 , 23.95, 21.63, 17.43, 25.47, 33.54, 15.96, 21.19,
#        26.  , 12.55, 16.9 , 22.3 , 12.9 , 13.5 , 17.84, 27.28, 24.04,
#        22.7 , 16.  , 17.6 , 21.7 , 20.45, 17.14, 19.6 , 20.4 , 12.63,
# ...

# %%
df['Mileage']=pd.to_numeric(df['Mileage'],errors='coerce')
df['Mileage']
# Out:
# 0        19.70
# 1        18.90
# 2        17.00
# 3        20.92
# 4        22.77
#          ...
# 15406    19.81
# 15407    17.50
# 15408    21.14
# 15409    16.00
# 15410    18.00
# Name: Mileage, Length: 15411, dtype: float64

# %%
df['Mileage'].dtype
# Out:
# dtype('float64')

# %%
df['Mileage'].isna().sum()
# Out:
# np.int64(0)

# %%
df = df[(df['Mileage'] > 0) & (df['Mileage'] < 100)]
df
# Out:
#               Car_Name     Brand     Model  Vehicle_Age  Km_Driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       I20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       I10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    Xuv500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       Seller_Type Fuel_Type Transmission_Type  Mileage  Engine  Max_Power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df['Mileage']=df['Mileage'].astype(int)
df['Mileage']
# Out:
# 0        19
# 1        18
# 2        17
# 3        20
# 4        22
#          ..
# 15406    19
# 15407    17
# 15408    21
# 15409    16
# 15410    18
# Name: Mileage, Length: 15411, dtype: int64

# %%
df.head(2)
# Out:
#         Car_Name    Brand  Model  Vehicle_Age  Km_Driven Seller_Type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
#
#   Fuel_Type Transmission_Type  Mileage  Engine  Max_Power  Seats  \
# 0    Petrol            Manual       19     796       46.3      5
# 1    Petrol            Manual       18    1197       82.0      5
#
#    Selling_Price
# 0         120000
# 1         550000

# %%
# clean Engine columns

df['Engine'].unique()
# Out:
# array([ 796, 1197,  998, 1498, 1582, 1461, 1998, 1248, 2143, 2494, 1598,
#        1497, 2523, 2982,  999, 1199, 1086, 2179, 1396, 1198, 1590, 1997,
#        1493, 1120, 1196, 1186, 1061,  799, 1796, 2993, 1298, 3198, 1995,
#        1373, 1591, 1968, 1399, 1047, 1353, 2755, 1395, 2498, 1999, 2953,
#        2393, 2967, 2998, 2995, 1956, 1462, 1799, 2499, 1451, 1194, 1798,
#        2694, 1496, 1969, 2487, 3604, 1499, 2987, 1599, 2354, 1950, 2148,
#        4134, 2400, 1984, 2979, 2609, 2092, 5998, 1330, 2956, 3598, 2362,
#         793, 1368, 3597, 1991, 5461, 1343, 2497, 4367, 1797, 3498, 2698,
#        1896, 2999, 3855, 4806, 1985, 2771, 2157, 3628, 2198, 2996, 2199,
#        4395, 3456, 4663, 2773, 6592, 2495, 1781, 2997, 1597, 2596, 4163])

# %%
df['Engine'] = df['Engine'].astype('string') + ' cc'
df['Engine']
# Out:
# 0         796 cc
# 1        1197 cc
# 2        1197 cc
# 3         998 cc
# 4        1498 cc
#           ...
# 15406    1086 cc
# 15407    1373 cc
# 15408    1498 cc
# 15409    2179 cc
# 15410    1497 cc
# Name: Engine, Length: 15411, dtype: string

# %%
df.head(5)
# Out:
#         Car_Name    Brand     Model  Vehicle_Age  Km_Driven Seller_Type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       I20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   Fuel_Type Transmission_Type  Mileage   Engine  Max_Power  Seats  \
# 0    Petrol            Manual       19   796 cc      46.30      5
# 1    Petrol            Manual       18  1197 cc      82.00      5
# 2    Petrol            Manual       17  1197 cc      80.00      5
# 3    Petrol            Manual       20   998 cc      67.10      5
# 4    Diesel            Manual       22  1498 cc      98.59      5
#
#    Selling_Price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df['Engine'].isna().sum()
# Out:
# np.int64(0)

# %%
# clean Max_Power columns
df['Max_Power'].value_counts()
# Out:
# Max_Power
# 74.00     791
# 88.50     589
# 81.80     544
# 98.60     424
# 67.04     390
#          ...
# 450.00      1
# 258.81      1
# 459.00      1
# 151.89      1
# 177.01      1
# Name: count, Length: 342, dtype: int64

# %%
df['Max_Power'].duplicated().sum()
# Out:
# np.int64(15069)

# %%
# clean Seats columns
df['Seats'].value_counts()
# Out:
# Seats
# 5    12910
# 7     1922
# 8      311
# 6      127
# 4       77
# 9       55
# 2        7
# 0        2
# Name: count, dtype: int64

# %%
df['Seats'].isna().sum()
# Out:
# np.int64(0)

# %%
## clean Selling_Price columns
df['Selling_Price'].unique()
# Out:
# array([ 120000,  550000,  215000, ..., 1640000,  386000,  456000],
#       shape=(1086,))

# %%
df['Selling_Price'].isna().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('car_data_clean.csv', index=False)

# %%
df
# Out:
#               Car_Name     Brand     Model  Vehicle_Age  Km_Driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       I20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       I10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    Xuv500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       Seller_Type Fuel_Type Transmission_Type  Mileage   Engine  Max_Power  \
# 0      Individual    Petrol            Manual       19   796 cc      46.30
# ...
